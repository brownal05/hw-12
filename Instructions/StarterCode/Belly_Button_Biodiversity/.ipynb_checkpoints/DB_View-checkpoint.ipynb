# %%
import datetime as dt
import numpy as np
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify

# %%
engine = create_engine("sqlite:///db/bellybutton.sqlite")
Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)

# %%
Base.classes.keys()
# Out:
# ['sample_metadata', 'samples']

# %%
Samples = Base.classes.samples
Meta = Base.classes.sample_metadata

# %%
samples = session.query(Samples).first()
samples.__dict__
# Out:
# {'1233': 0,
#  '1234': 0,
#  '1235': 0,
#  '1236': 0,
#  '1237': 0,
#  '1238': 0,
#  '1242': 0,
#  '1243': 0,
#  '1246': 0,
#  '1253': 0,
#  '1254': 0,
#  '1258': 0,
#  '1259': 0,
#  '1260': 0,
#  '1264': 0,
#  '1265': 0,
#  '1273': 0,
#  '1275': 0,
#  '1276': 0,
#  '1277': 0,
#  '1278': 0,
#  '1279': 0,
#  '1280': 0,
#  '1281': 0,
#  '1282': 0,
#  '1283': 0,
#  '1284': 0,
#  '1285': 0,
#  '1286': None,
#  '1287': 0,
#  '1288': 0,
#  '1289': 0,
#  '1290': 0,
#  '1291': 0,
#  '1292': 0,
#  '1293': 0,
#  '1294': 0,
#  '1295': 0,
#  '1296': 0,
#  '1297': 0,
#  '1298': 0,
#  '1308': 0,
#  '1309': 0,
#  '1310': 0,
#  '1374': 0,
#  '1415': 0,
#  '1439': 0,
#  '1441': 0,
#  '1443': 0,
#  '1486': 0,
#  '1487': 0,
#  '1489': 0,
#  '1490': 0,
#  '1491': 0,
#  '1494': 0,
#  '1495': 0,
#  '1497': 0,
#  '1499': 0,
#  '1500': 0,
#  '1501': 0,
#  '1502': 0,
#  '1503': 0,
#  '1504': 0,
#  '1505': 0,
#  '1506': 0,
#  '1507': 0,
#  '1508': 0,
#  '1510': 0,
#  '1511': 0,
#  '1512': 0,
#  '1513': 0,
#  '1514': 0,
#  '1515': 0,
#  '1516': 0,
#  '1517': 0,
#  '1518': 0,
#  '1519': 0,
#  '1521': 0,
#  '1524': 0,
#  '1526': 0,
#  '1527': 0,
#  '1530': 0,
#  '1531': 0,
#  '1532': 0,
#  '1533': 0,
#  '1534': 0,
#  '1535': 0,
#  '1536': 0,
#  '1537': 0,
#  '1539': 0,
#  '1540': 0,
#  '1541': 0,
#  '1542': 0,
#  '1543': 0,
#  '1544': 0,
#  '1545': 0,
#  '1546': 0,
#  '1547': 0,
#  '1548': 0,
#  '1549': 0,
#  '1550': 0,
#  '1551': 0,
#  '1552': 0,
#  '1553': 0,
#  '1554': 0,
#  '1555': 0,
#  '1556': 0,
#  '1557': 0,
#  '1558': 0,
#  '1561': 0,
#  '1562': 0,
#  '1563': 0,
#  '1564': 0,
#  '1572': 0,
#  '1573': 0,
#  '1574': 0,
#  '1576': 0,
#  '1577': 0,
#  '1581': 0,
#  '1601': 0,
#  '940': 0,
#  '941': 0,
#  '943': 0,
#  '944': 0,
#  '945': 0,
#  '946': 0,
#  '947': 0,
#  '948': 0,
#  '949': 0,
#  '950': 0,
#  '952': 0,
#  '953': 0,
#  '954': 0,
#  '955': 0,
#  '956': 0,
#  '958': 0,
#  '959': 0,
#  '960': 0,
#  '961': 0,
#  '962': 0,
#  '963': 0,
#  '964': 0,
#  '966': 1,
#  '967': 0,
#  '968': 0,
#  '969': 0,
#  '970': 0,
#  '971': 0,
#  '972': 0,
#  '973': 0,
#  '974': 0,
#  '975': 0,
#  '978': 0,
#  '_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1fc46307ac8>,
#  'otu_id': 1,
#  'otu_label': 'Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Halococcus'}

# %%
meta = session.query(Meta).first()
meta.__dict__
# Out:
# {'AGE': 24.0,
#  'BBTYPE': 'I',
#  'CAT': 'no',
#  'COUNTRY012': 'usa',
#  'COUNTRY1319': 'usa',
#  'DOG': 'no',
#  'ETHNICITY': 'Caucasian',
#  'EVENT': 'BellyButtonsScienceOnline',
#  'GENDER': 'F',
#  'IMPSURFACE013': 8852.0,
#  'IMPSURFACE1319': '1',
#  'LOCATION': 'Beaufort/NC',
#  'MMAXTEMP013': 54.5,
#  'MMAXTEMP1319': 33.99000168,
#  'NPP013': 37.17222214,
#  'NPP1319': None,
#  'PFC013': None,
#  'PFC1319': 25.5,
#  'WFREQ': 2.0,
#  'ZIP012': '22306',
#  'ZIP1319': '22306',
#  '_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1fc46326828>,
#  'sample': 940}

# %%
samples.__dict__
# Out:
# mappingproxy({'1233': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161eb8>,
#               '1234': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161f68>,
#               '1235': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166048>,
#               '1236': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461660f8>,
#               '1237': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461661a8>,
#               '1238': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166258>,
#               '1242': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166308>,
#               '1243': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461663b8>,
#               '1246': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166468>,
#               '1253': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166518>,
#               '1254': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461665c8>,
#               '1258': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166678>,
#               '1259': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166728>,
#               '1260': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461667d8>,
#               '1264': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166888>,
#               '1265': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166938>,
#               '1273': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461669e8>,
#               '1275': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166a98>,
#               '1276': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166b48>,
#               '1277': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166bf8>,
#               '1278': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166ca8>,
#               '1279': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166d58>,
#               '1280': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166e08>,
#               '1281': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166eb8>,
#               '1282': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46166f68>,
#               '1283': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d048>,
#               '1284': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d0f8>,
#               '1285': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d1a8>,
#               '1286': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d258>,
#               '1287': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d308>,
#               '1288': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d3b8>,
#               '1289': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d468>,
#               '1290': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d518>,
#               '1291': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d5c8>,
#               '1292': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d678>,
#               '1293': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d728>,
#               '1294': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d7d8>,
#               '1295': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d888>,
#               '1296': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d938>,
#               '1297': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616d9e8>,
#               '1298': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616da98>,
#               '1308': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616db48>,
#               '1309': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616dbf8>,
#               '1310': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616dca8>,
#               '1374': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616dd58>,
#               '1415': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616de08>,
#               '1439': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616deb8>,
#               '1441': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4616df68>,
#               '1443': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173048>,
#               '1486': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461730f8>,
#               '1487': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461731a8>,
#               '1489': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173258>,
#               '1490': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173308>,
#               '1491': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461733b8>,
#               '1494': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173468>,
#               '1495': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173518>,
#               '1497': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461735c8>,
#               '1499': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173678>,
#               '1500': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173728>,
#               '1501': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461737d8>,
#               '1502': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173888>,
#               '1503': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173938>,
#               '1504': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461739e8>,
#               '1505': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173a98>,
#               '1506': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173b48>,
#               '1507': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173bf8>,
#               '1508': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173ca8>,
#               '1510': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173d58>,
#               '1511': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173e08>,
#               '1512': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173eb8>,
#               '1513': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46173f68>,
#               '1514': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b048>,
#               '1515': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b0f8>,
#               '1516': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b1a8>,
#               '1517': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b258>,
#               '1518': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b308>,
#               '1519': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b3b8>,
#               '1521': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b468>,
#               '1524': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b518>,
#               '1526': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b5c8>,
#               '1527': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b678>,
#               '1530': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b728>,
#               '1531': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b7d8>,
#               '1532': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b888>,
#               '1533': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b938>,
#               '1534': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617b9e8>,
#               '1535': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617ba98>,
#               '1536': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617bb48>,
#               '1537': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617bbf8>,
#               '1539': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617bca8>,
#               '1540': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617bd58>,
#               '1541': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617be08>,
#               '1542': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617beb8>,
#               '1543': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4617bf68>,
#               '1544': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e048>,
#               '1545': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e0f8>,
#               '1546': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e1a8>,
#               '1547': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e258>,
#               '1548': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e308>,
#               '1549': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e3b8>,
#               '1550': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e468>,
#               '1551': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e518>,
#               '1552': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e5c8>,
#               '1553': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e678>,
#               '1554': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e728>,
#               '1555': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e7d8>,
#               '1556': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e888>,
#               '1557': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e938>,
#               '1558': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613e9e8>,
#               '1561': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613ea98>,
#               '1562': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613eb48>,
#               '1563': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613ebf8>,
#               '1564': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613eca8>,
#               '1572': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613ed58>,
#               '1573': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613ee08>,
#               '1574': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613eeb8>,
#               '1576': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc4613ef68>,
#               '1577': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46144048>,
#               '1581': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461440f8>,
#               '1601': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461441a8>,
#               '940': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461557d8>,
#               '941': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155888>,
#               '943': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155938>,
#               '944': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461559e8>,
#               '945': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155a98>,
#               '946': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155b48>,
#               '947': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155bf8>,
#               '948': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155ca8>,
#               '949': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155d58>,
#               '950': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155e08>,
#               '952': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155eb8>,
#               '953': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155f68>,
#               '954': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161048>,
#               '955': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461610f8>,
#               '956': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461611a8>,
#               '958': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161258>,
#               '959': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161308>,
#               '960': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461613b8>,
#               '961': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161468>,
#               '962': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161518>,
#               '963': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461615c8>,
#               '964': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161678>,
#               '966': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161728>,
#               '967': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461617d8>,
#               '968': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161888>,
#               '969': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161938>,
#               '970': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc461619e8>,
#               '971': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161a98>,
#               '972': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161b48>,
#               '973': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161bf8>,
#               '974': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161ca8>,
#               '975': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161d58>,
#               '978': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46161e08>,
#               '__doc__': None,
#               '__init__': <function __init__>,
#               '__mapper__': <Mapper at 0x1fc460cc9b0; samples>,
#               '__module__': 'sqlalchemy.ext.automap',
#               '__table__': Table('samples', MetaData(bind=None), Column('otu_id', INTEGER(), table=<samples>, primary_key=True, nullable=False), Column('otu_label', TEXT(), table=<samples>), Column('940', INTEGER(), table=<samples>), Column('941', INTEGER(), table=<samples>), Column('943', INTEGER(), table=<samples>), Column('944', INTEGER(), table=<samples>), Column('945', INTEGER(), table=<samples>), Column('946', INTEGER(), table=<samples>), Column('947', INTEGER(), table=<samples>), Column('948', INTEGER(), table=<samples>), Column('949', INTEGER(), table=<samples>), Column('950', INTEGER(), table=<samples>), Column('952', INTEGER(), table=<samples>), Column('953', INTEGER(), table=<samples>), Column('954', INTEGER(), table=<samples>), Column('955', INTEGER(), table=<samples>), Column('956', INTEGER(), table=<samples>), Column('958', INTEGER(), table=<samples>), Column('959', INTEGER(), table=<samples>), Column('960', INTEGER(), table=<samples>), Column('961', INTEGER(), table=<samples>), Column('962', INTEGER(), table=<samples>), Column('963', INTEGER(), table=<samples>), Column('964', INTEGER(), table=<samples>), Column('966', INTEGER(), table=<samples>), Column('967', INTEGER(), table=<samples>), Column('968', INTEGER(), table=<samples>), Column('969', INTEGER(), table=<samples>), Column('970', INTEGER(), table=<samples>), Column('971', INTEGER(), table=<samples>), Column('972', INTEGER(), table=<samples>), Column('973', INTEGER(), table=<samples>), Column('974', INTEGER(), table=<samples>), Column('975', INTEGER(), table=<samples>), Column('978', INTEGER(), table=<samples>), Column('1233', INTEGER(), table=<samples>), Column('1234', INTEGER(), table=<samples>), Column('1235', INTEGER(), table=<samples>), Column('1236', INTEGER(), table=<samples>), Column('1237', INTEGER(), table=<samples>), Column('1238', INTEGER(), table=<samples>), Column('1242', INTEGER(), table=<samples>), Column('1243', INTEGER(), table=<samples>), Column('1246', INTEGER(), table=<samples>), Column('1253', INTEGER(), table=<samples>), Column('1254', INTEGER(), table=<samples>), Column('1258', INTEGER(), table=<samples>), Column('1259', INTEGER(), table=<samples>), Column('1260', INTEGER(), table=<samples>), Column('1264', INTEGER(), table=<samples>), Column('1265', INTEGER(), table=<samples>), Column('1273', INTEGER(), table=<samples>), Column('1275', INTEGER(), table=<samples>), Column('1276', INTEGER(), table=<samples>), Column('1277', INTEGER(), table=<samples>), Column('1278', INTEGER(), table=<samples>), Column('1279', INTEGER(), table=<samples>), Column('1280', INTEGER(), table=<samples>), Column('1281', INTEGER(), table=<samples>), Column('1282', INTEGER(), table=<samples>), Column('1283', INTEGER(), table=<samples>), Column('1284', INTEGER(), table=<samples>), Column('1285', INTEGER(), table=<samples>), Column('1286', INTEGER(), table=<samples>), Column('1287', INTEGER(), table=<samples>), Column('1288', INTEGER(), table=<samples>), Column('1289', INTEGER(), table=<samples>), Column('1290', INTEGER(), table=<samples>), Column('1291', INTEGER(), table=<samples>), Column('1292', INTEGER(), table=<samples>), Column('1293', INTEGER(), table=<samples>), Column('1294', INTEGER(), table=<samples>), Column('1295', INTEGER(), table=<samples>), Column('1296', INTEGER(), table=<samples>), Column('1297', INTEGER(), table=<samples>), Column('1298', INTEGER(), table=<samples>), Column('1308', INTEGER(), table=<samples>), Column('1309', INTEGER(), table=<samples>), Column('1310', INTEGER(), table=<samples>), Column('1374', INTEGER(), table=<samples>), Column('1415', INTEGER(), table=<samples>), Column('1439', INTEGER(), table=<samples>), Column('1441', INTEGER(), table=<samples>), Column('1443', INTEGER(), table=<samples>), Column('1486', INTEGER(), table=<samples>), Column('1487', INTEGER(), table=<samples>), Column('1489', INTEGER(), table=<samples>), Column('1490', INTEGER(), table=<samples>), Column('1491', INTEGER(), table=<samples>), Column('1494', ...
#               '_sa_class_manager': <ClassManager of <class 'sqlalchemy.ext.automap.samples'> at 1fc46155570>,
#               'otu_id': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155620>,
#               'otu_label': <sqlalchemy.orm.attributes.InstrumentedAttribute at 0x1fc46155728>})
